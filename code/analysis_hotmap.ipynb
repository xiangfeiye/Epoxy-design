# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import random
from tqdm import trange
import pickle 
import shap
import optuna
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process.kernels import ConstantKernel, RBF, WhiteKernel, DotProduct, Matern
from sklearn.model_selection import cross_val_score

with open('shap_states_1229.pth', 'rb') as f:
    states = pickle.load(f)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
grid = 100
sample = []
for i in range(grid+1):
    for j in range(grid+1):
        sample.append(np.array([i,j])*1/grid)
        
sample_x = np.array(sample)
df = pd.DataFrame()

# %%
df = pd.DataFrame()
target = 'strength'
model = states[target]['model']
ratio = 0.5
# stage 1
samples = np.ones([len(sample_x),6])*ratio
samples[:,0:2] = sample_x
result = model.predict(samples)
df[['T', 't']] = sample_x
df[target+'_result1'] = result

# stage2
samples = np.ones([len(sample_x),6])*ratio
samples[:,2:4] = sample_x
result = model.predict(samples)
df[target+'_result2'] = result

# stage3
samples = np.ones([len(sample_x),6])*ratio
samples[:,4:6] = sample_x
result = model.predict(samples)
df[target+'_result3'] = result

target = 'modulus'
model = states[target]['model']
# stage 1
samples = np.ones([len(sample_x),6])*ratio
samples[:,0:2] = sample_x
result = model.predict(samples)
df[target+'_result1'] = result

# stage2
samples = np.ones([len(sample_x),6])*ratio
samples[:,2:4] = sample_x
result = model.predict(samples)
df[target+'_result2'] = result

# stage3
samples = np.ones([len(sample_x),6])*ratio
samples[:,4:6] = sample_x
result = model.predict(samples)
df[target+'_result3'] = result

target = 'elongation'
model = states[target]['model']
# stage 1
samples = np.ones([len(sample_x),6])*ratio
samples[:,0:2] = sample_x
result = model.predict(samples)
df[target+'_result1'] = result

# stage2
samples = np.ones([len(sample_x),6])*ratio
samples[:,2:4] = sample_x
result = model.predict(samples)
df[target+'_result2'] = result

# stage3
samples = np.ones([len(sample_x),6])*ratio
samples[:,4:6] = sample_x
result = model.predict(samples)
df[target+'_result3'] = result

target = 'tg'
model = states[target]['model']
# stage 1
samples = np.ones([len(sample_x),6])*ratio
samples[:,0:2] = sample_x
result = model.predict(samples)
df[target+'_result1'] = result

# stage2
samples = np.ones([len(sample_x),6])*ratio
samples[:,2:4] = sample_x
result = model.predict(samples)
df[target+'_result2'] = result

# stage3
samples = np.ones([len(sample_x),6])*ratio
samples[:,4:6] = sample_x
result = model.predict(samples)
df[target+'_result3'] = result

df.to_csv('con_result_%s.csv'%ratio,index=False)
